# %% [markdown]
# <a href="https://colab.research.google.com/github/adityaavinashrex-rgb/yolo-ppe-project/blob/main-scripts-and-instructions/Primitive_YOLO_GPU_ver1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
#checks if we are running on GPU and shows specs
# Out:
# Mon Jun 15 17:10:49 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install torch numpy opencv-python ultralytics
#this is a general command I am using for this project, there is no need for all these libraries the most important is ultralytics as it is where YOLO is housed
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
#sets up YOLO
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 969, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {list(MODES)}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=checks'. Valid modes are ['track', 'val', 'predict', 'train', 'benchmark', 'export'].
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['segment', 'pose', 'obb', 'detect', 'semantic', 'classify']
#                 MODE (required) is one of ['track', 'val', 'predict', 'train', 'benchmark', 'export']
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
# %pip install roboflow
from roboflow import Roboflow
rf= Roboflow(api_key="SL9H0zXQ0sGkW8MeO3Ti")
project= rf.workspace("roboflow-universe-projects").project("personal-protective-equipment-combined-model")
dataset = project.version(8).download("yolov8")
#installs dataset from roboflow, which is what I am going to be mainly using for the first few models (check out roboflow datasets here: https://universe.roboflow.com/)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 141.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %%
from ultralytics import YOLO

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=10 imgsz=480
#train the model
# Out:
# ...
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO
# !yolo task=detect mode=predict model=/content/best.pt source="/content/test_construction.jpg" conf=0.30 imgsz=480 save=true project=/Inferences name=construction_colab_inference_5 exist_ok=True
#run an inference aka "test" the model
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,008,378 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/test_construction.jpg: 480x256 1 Hardhat, 39.2ms
# Speed: 12.3ms preprocess, 39.2ms inference, 40.0ms postprocess per image at shape (1, 3, 480, 256)
# Results saved to /Inferences/construction_colab_inference_5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
